# %% [markdown]
# Muhammad Alpi Ashari
# 2209106017
# Informatika A'2022
# POSTTEST2 KB

# %% [markdown]
# -Langkah Pertama
# Mengimport Pandas dan Prettytable
# Mengimport Dataset
# Menampilkan Statistik dari Attribute bertipe Angka

# %%
import pandas as pd
import prettytable as prtl
alpi = pd.read_csv('music_genre.csv')
alpi.describe()
# Out:
#         instance_id    popularity  acousticness  danceability   duration_ms  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  5.000000e+04
# mean   55888.396360     44.220420      0.306383      0.558241  2.212526e+05
# std    20725.256253     15.542008      0.341340      0.178632  1.286720e+05
# min    20002.000000      0.000000      0.000000      0.059600 -1.000000e+00
# 25%    37973.500000     34.000000      0.020000      0.442000  1.748000e+05
# 50%    55913.500000     45.000000      0.144000      0.568000  2.192810e+05
# 75%    73863.250000     56.000000      0.552000      0.687000  2.686122e+05
# max    91759.000000     99.000000      0.996000      0.986000  4.830606e+06
#
#              energy  instrumentalness      liveness      loudness  \
# count  50000.000000      50000.000000  50000.000000  50000.000000
# mean       0.599755          0.181601      0.193896     -9.133761
# std        0.264559          0.325409      0.161637      6.162990
# ...

# %% [markdown]
# -Langkah KeDua
# Menampilkan Info dari Dataset

# %%
alpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50005 entries, 0 to 50004
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       50000 non-null  float64
#  1   artist_name       50000 non-null  object
#  2   track_name        50000 non-null  object
#  3   popularity        50000 non-null  float64
#  4   acousticness      50000 non-null  float64
#  5   danceability      50000 non-null  float64
#  6   duration_ms       50000 non-null  float64
#  7   energy            50000 non-null  float64
#  8   instrumentalness  50000 non-null  float64
#  9   key               50000 non-null  object
#  10  liveness          50000 non-null  float64
#  11  loudness          50000 non-null  float64
#  12  mode              50000 non-null  object
#  13  speechiness       50000 non-null  float64
#  14  tempo             50000 non-null  object
#  15  obtained_date     50000 non-null  object
# ...

# %% [markdown]
# -Langkah KeTiga
# Menampilkan 10 record pertama dari Dataset dari Attribute bertipe Angka

# %%
alpi.select_dtypes(include=['int64', 'float64']).head(10)
# Out:
#    instance_id  popularity  acousticness  danceability  duration_ms  energy  \
# 0      32894.0        27.0       0.00468         0.652         -1.0   0.941
# 1      46652.0        31.0       0.01270         0.622     218293.0   0.890
# 2      30097.0        28.0       0.00306         0.620     215613.0   0.755
# 3      62177.0        34.0       0.02540         0.774     166875.0   0.700
# 4      24907.0        32.0       0.00465         0.638     222369.0   0.587
# 5      89064.0        47.0       0.00523         0.755     519468.0   0.731
# 6      43760.0        46.0       0.02890         0.572     214408.0   0.803
# 7      30738.0        43.0       0.02970         0.809     416132.0   0.706
# 8      84950.0        39.0       0.00299         0.509     292800.0   0.921
# 9      56950.0        22.0       0.00934         0.578     204800.0   0.731
#
#    instrumentalness  liveness  loudness  speechiness  valence
# 0          0.792000    0.1150    -5.201       0.0748    0.759
# ...

# %% [markdown]
# -Langkah KeEmpat
# Menampilkan informasi Jumlah Record, Jumlah Attribute, Nama Attribute, Jumlah Attribute dengan Tipe Angka

# %%
data = {}

data['Jumlah Record'] = alpi.shape[0]
data['Jumlah Attribute'] = alpi.shape[1]
data['Nama Attribute'] = alpi.columns.tolist()
data['Jumlah Attribute Dengan Tipe Angka'] = alpi.select_dtypes(include=['int64', 'float64']).shape[1]

dictKeys = list(data.keys())

table = prtl.PrettyTable()
table.add_column(dictKeys[0], [data['Jumlah Record']])
table.add_column(dictKeys[1], [data['Jumlah Attribute']])
table.add_column(dictKeys[2], ['\n'.join(data['Nama Attribute'])])
table.add_column(dictKeys[3], [data['Jumlah Attribute Dengan Tipe Angka']])
print(table)
# Out:
# +---------------+------------------+------------------+------------------------------------+
# | Jumlah Record | Jumlah Attribute |  Nama Attribute  | Jumlah Attribute Dengan Tipe Angka |
# +---------------+------------------+------------------+------------------------------------+
# |     50005     |        18        |   instance_id    |                 11                 |
# |               |                  |   artist_name    |                                    |
# |               |                  |    track_name    |                                    |
# |               |                  |    popularity    |                                    |
# |               |                  |   acousticness   |                                    |
# |               |                  |   danceability   |                                    |
# |               |                  |   duration_ms    |                                    |
# ...

# %% [markdown]
# -Langkah KeLima
# Menampilkan nilai dataset pada baris, menggunakan 3 digit NIM terakhir(017)
# Data terakhir dan kolom ke 4 sampai kolom terakhir menggunakan 2 metode yaitu, loc dan iloc

# %%
alpi.iloc[17:, 3:]
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 17           29.0       0.15800         0.660     266282.0   0.784
# 18           35.0       0.00006         0.259     185333.0   0.687
# 19           50.0       0.02810         0.656     307328.0   0.653
# 20           44.0       0.00804         0.516     241877.0   0.920
# 21           29.0       0.00998         0.854     227756.0   0.335
# ...           ...           ...           ...          ...     ...
# 50000        59.0       0.03340         0.913         -1.0   0.574
# 50001        72.0       0.15700         0.709     251860.0   0.362
# 50002        51.0       0.00597         0.693     189483.0   0.763
# 50003        65.0       0.08310         0.782     262773.0   0.472
# 50004        67.0       0.10200         0.862     267267.0   0.642
#
#        instrumentalness key  liveness  loudness   mode  speechiness  \
# 17             0.000279   C    0.0978    -4.396  Minor       0.0571
# ...

# %%
alpi.loc[17:, data['Nama Attribute'][3:]]
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 17           29.0       0.15800         0.660     266282.0   0.784
# 18           35.0       0.00006         0.259     185333.0   0.687
# 19           50.0       0.02810         0.656     307328.0   0.653
# 20           44.0       0.00804         0.516     241877.0   0.920
# 21           29.0       0.00998         0.854     227756.0   0.335
# ...           ...           ...           ...          ...     ...
# 50000        59.0       0.03340         0.913         -1.0   0.574
# 50001        72.0       0.15700         0.709     251860.0   0.362
# 50002        51.0       0.00597         0.693     189483.0   0.763
# 50003        65.0       0.08310         0.782     262773.0   0.472
# 50004        67.0       0.10200         0.862     267267.0   0.642
#
#        instrumentalness key  liveness  loudness   mode  speechiness  \
# 17             0.000279   C    0.0978    -4.396  Minor       0.0571
# ...

# %% [markdown]
# -Langkah KeEnam
# Menampilka jumlah nilai dari semua Attribute yang bernilai object

# %%
listobject = alpi.select_dtypes(include=['object']).columns.tolist()
listobject.pop(0)

for i in listobject:
    print(alpi[i].value_counts())
# Out:
# Home               16
# Forever            15
# Without You        14
# Summertime         13
# Fire               13
#                    ..
# Build               1
# In My Home          1
# Fire Water Burn     1
# Bitter End          1
# Hip Hop Hooray      1
# Name: track_name, Length: 41699, dtype: int64
# G     5727
# C     5522
# C#    5405
# D     5265
# A     4825
# F     4341
# B     3789
# E     3760
# A#    3356
# G#    3319
# F#    3101
# D#    1590
# Name: key, dtype: int64
# Major    32099
# Minor    17901
# Name: mode, dtype: int64
# ?                     4980
# 140.007                 17
# 120.0                   17
# 100.00299999999999      16
# 100.014                 15
#                       ...
# 137.046                  1
# 136.378                  1
# 93.041                   1
# 113.98200000000001       1
# 99.20100000000001        1
# Name: tempo, Length: 29394, dtype: int64
# 4-Apr    44748
# 3-Apr     4067
# 5-Apr      784
# 1-Apr      400
# ...
